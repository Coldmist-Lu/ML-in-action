# %% [markdown]
# # Tensorflow 4 - 自定义模型

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target.reshape(-1, 1), random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
X_new_scaled = X_test_scaled

# %% [markdown]
# ## 1 模型自定义

# %%
class ResidualBlock(keras.layers.Layer):
    def __init__(self, n_layers, n_neurons, **kwargs):
        super().__init__(**kwargs)
        self.hidden = [keras.layers.Dense(n_neurons, activation='elu',
                                          kernel_initializer='he_normal')
                       for _ in range(n_layers)]
        
    def call(self, inputs):
        Z = inputs
        for layer in self.hidden:
            Z = layer(Z)
        return inputs + Z

# %%
class ResidualRegressor(keras.models.Model):
    def __init__(self, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.hidden1 = keras.layers.Dense(30, activation='elu',
                                          kernel_initializer='he_normal')
        self.block1 = ResidualBlock(2, 30)
        self.block2 = ResidualBlock(2, 30)
        self.out = keras.layers.Dense(output_dim)
        
    def call(self, inputs):
        Z = self.hidden1(inputs)
        for _ in range(1 + 3):
            Z = self.block1(Z)
        Z = self.block2(Z)
        return self.out(Z)

# %%
model = ResidualRegressor(1)
model.compile(loss='mse', optimizer='nadam')
history = model.fit(X_train_scaled, y_train, epochs=5)
score = model.evaluate(X_test_scaled, y_test)
y_pred = model.predict(X_new_scaled)
# Out:
# Epoch 1/5
# 363/363 [==============================] - 3s 7ms/step - loss: 7.3354
# Epoch 2/5
# 363/363 [==============================] - 2s 7ms/step - loss: 1.0312
# Epoch 3/5
# 363/363 [==============================] - 2s 7ms/step - loss: 1.0493
# Epoch 4/5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.7142
# Epoch 5/5
# ...
# 162/162 [==============================] - 0s 2ms/step - loss: 0.4843

# %% [markdown]
# * save 方法要存成 ckpt:

# %%
model.save('./models/TF4-model1.ckpt') # 注意不能保存成 h5
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tf2_20/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./models/TF4-model1.ckpt/assets

# %%
model = keras.models.load_model('./models/TF4-model1.ckpt')
history = model.fit(X_train_scaled, y_train, epochs=5)
# Out:
# Epoch 1/5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.7222
# Epoch 2/5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.4904
# Epoch 3/5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.4747
# Epoch 4/5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.5714
# Epoch 5/5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.5135

# %% [markdown]
# * 上述模型也可以用顺序 API 构建：

# %%
block1 = ResidualBlock(2, 30)
model = keras.models.Sequential([
    keras.layers.Dense(30, activation='elu', kernel_initializer='he_normal'),
    block1, block1, block1, block1,
    ResidualBlock(2, 30),
    keras.layers.Dense(1),
])
model.compile(loss='mse', optimizer='nadam')

# %%
history = model.fit(X_train_scaled, y_train, epochs=3)
score = model.evaluate(X_test_scaled, y_test)
y_pred = model.predict(X_new_scaled)
# Out:
# Epoch 1/3
# 363/363 [==============================] - 2s 6ms/step - loss: 4.8838
# Epoch 2/3
# 363/363 [==============================] - 2s 6ms/step - loss: 0.4721
# Epoch 3/3
# ...
# 162/162 [==============================] - 0s 2ms/step - loss: 0.3748

# %% [markdown]
# ## 2 基于模型内部自定义损失和指标
#
# * 输出重建损失。

# %%
class ReconstructingRegressor(keras.models.Model):
    def __init__(self, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.hidden = [keras.layers.Dense(30, activation='selu',
                                          kernel_initializer='lecun_normal')
                       for _ in range(5)]
        self.out = keras.layers.Dense(output_dim)
        self.reconstruct = keras.layers.Dense(8)
        self.reconstruction_mean = keras.metrics.Mean(name='reconstruction_error')
        
    def call(self, inputs, training=None):
        Z = inputs
        for layer in self.hidden:
            Z = layer(Z)
        reconstruction = self.reconstruct(Z)
        recon_loss = tf.reduce_mean(tf.square(reconstruction - inputs))
        self.add_loss(0.05 * recon_loss)
        if training:
            result = self.reconstruction_mean(recon_loss)
            self.add_metric(result)
        return self.out(Z)

# %%
model = ReconstructingRegressor(1)
model.compile(loss='mse', optimizer='nadam')
history = model.fit(X_train_scaled, y_train, epochs=2)
y_pred = model.predict(X_test_scaled)
# Out:
# Epoch 1/2
# 363/363 [==============================] - 3s 7ms/step - loss: 0.6718 - reconstruction_error: 0.7296
# Epoch 2/2
# 363/363 [==============================] - 2s 7ms/step - loss: 0.4212 - reconstruction_error: 0.3625

# %% [markdown]
# ## 3 自动微分计算梯度

# %% [markdown]
# ### 3-1 自动微分机制

# %%
def f(w1, w2):
    return 3 * w1 ** 2 + 2 * w1 * w2

# %%
w1, w2 = 5, 3
eps = 1e-6
(f(w1 + eps, w2) - f(w1, w2)) / eps # 手动微分
# Out:
# 36.000003007075065

# %% [markdown]
# * 创建一个 tf.GradientTape 上下文，自动记录涉及变量的每个操作，最后计算梯度。

# %%
w1, w2 = tf.Variable(5.), tf.Variable(3.)
with tf.GradientTape() as tape:
    z = f(w1, w2)
    
gradients = tape.gradient(z, [w1, w2])
gradients
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=36.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=10.0>]

# %% [markdown]
# ### 3-2 擦除与持久性
#
# * 调用 tape.gradient() 方法后，tape 会立即自动擦除，若两次调用将引发异常：

# %%
with tf.GradientTape() as tape:
    z = f(w1, w2)
    
dz_dw1 = tape.gradient(z, w1)
try:
    dz_dw2 = tape.gradient(z, w2)
except RuntimeError as ex:
    print(ex)
# Out:
# GradientTape.gradient can only be called once on non-persistent tapes.

# %% [markdown]
# * 若需要多次使用，则必须设置 tape 的持久性, 用完后还需要手动删除以释放资源：

# %%
with tf.GradientTape(persistent=True) as tape:
    z = f(w1, w2)
    
dz_dw1 = tape.gradient(z, w1)
dz_dw2 = tape.gradient(z, w2)
del tape
dz_dw1, dz_dw2
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=36.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=10.0>)

# %% [markdown]
# ### 3-3 常量
#
# * tape 只跟踪涉及变量的操作，若尝试变量以外的其他变量计算 z 的梯度，结果将为 None：

# %%
c1, c2 = tf.constant(5.), tf.constant(3.)
with tf.GradientTape() as tape:
    z = f(c1, c2)
    
gradients = tape.gradient(z, [c1, c2])
gradients
# Out:
# [None, None]

# %% [markdown]
# * 但是你可以强制 tape 观察所需的张量，记录所有操作，包括计算梯度：

# %%
with tf.GradientTape() as tape:
    tape.watch(c1)
    tape.watch(c2)
    z = f(c1, c2)
    
gradients = tape.gradient(z, [c1, c2])
gradients
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=36.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=10.0>]

# %% [markdown]
# ### 3-4 向量
#
# * 若 z 为一个向量，那么默认会计算各个向量的梯度之和。
# * 下面的例子，原本关于w1的导数为 6w1+2w2, 所以求导结果为(6\*5+2\*5)+(6\*5+2\*8)+(6\*5+2\*10)=40+46+50=136
# * 关于w2的导数为 2w1，所以求导结果为 2*5*3=30

# %%
with tf.GradientTape() as tape:
    z1 = f(w1, w2 + 2.)
    z2 = f(w1, w2 + 5.)
    z3 = f(w1, w2 + 7.)
    
tape.gradient([z1, z2, z3], [w1, w2])
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=136.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.0>]

# %% [markdown]
# * 所以这一结果相当于如下的结果：

# %%
with tf.GradientTape(persistent=True) as tape:
    z1 = f(w1, w2 + 2.)
    z2 = f(w1, w2 + 5.)
    z3 = f(w1, w2 + 7.)
    
print(tf.reduce_sum(tf.stack([tape.gradient(z, [w1, w2]) for z in (z1, z2, z3)]), axis=0))
del tape
# Out:
# tf.Tensor([136.  30.], shape=(2,), dtype=float32)

# %% [markdown]
# * 下面的方法用于自动计算二阶导数

# %%
with tf.GradientTape(persistent=True) as hessian_tape:
    with tf.GradientTape() as jacobian_tape:
        z = f(w1, w2)
    jacobians = jacobian_tape.gradient(z, [w1, w2])
hessians = [hessian_tape.gradient(jacobian, [w1, w2])
            for jacobian in jacobians]
del hessian_tape
# Out:
# [[<tf.Tensor: shape=(), dtype=float32, numpy=6.0>,
#   <tf.Tensor: shape=(), dtype=float32, numpy=2.0>],
#  [<tf.Tensor: shape=(), dtype=float32, numpy=2.0>, None]]

# %%
hessians
# Out:
# [[<tf.Tensor: shape=(), dtype=float32, numpy=6.0>,
#   <tf.Tensor: shape=(), dtype=float32, numpy=2.0>],
#  [<tf.Tensor: shape=(), dtype=float32, numpy=2.0>, None]]

# %%
jacobians
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=36.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=10.0>]

# %% [markdown]
# ### 3-5 阻止梯度传播

# %% [markdown]
# * 有时希望阻止一些梯度的反向传播，那么需要使用 tf.stop_gradient() 函数：

# %%
def f(w1, w2):
    return 3 * w1 ** 2 + tf.stop_gradient(2 * w1 * w2)

with tf.GradientTape() as tape:
    z = f(w1, w2)
    
tape.gradient(z, [w1, w2])
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=30.0>, None]

# %% [markdown]
# ### 3-6 梯度爆炸问题

# %% [markdown]
# * 当对一些存在数值问题的函数求导时，可能产生空值：

# %%
def my_softplus(z): # return value is just tf.nn.softplus(z)
    return tf.math.log(tf.exp(z) + 1.0)

x = tf.Variable(100.)
with tf.GradientTape() as tape:
    z = my_softplus(x)
    
tape.gradient(z, [x])
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=nan>]

# %% [markdown]
# * 此时我们就要用 @tf.custom_gradient 修饰来解决：

# %%
@tf.custom_gradient
def my_better_softplus(z):
    exp = tf.exp(z)
    def my_softplus_gradients(grad):
        return grad / (1 + 1 / exp) # 梯度手动求好
    return tf.math.log(exp + 1), my_softplus_gradients # 返回梯度

x = tf.Variable([1000.])
with tf.GradientTape() as tape:
    z = my_better_softplus(x)
    
z, tape.gradient(z, [x])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([inf], dtype=float32)>,
#  [<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>])

# %%
def my_better_softplus(z): # 防止梯度爆炸
    return tf.where(z > 30, z, tf.math.log(tf.exp(z) + 1.))

x = tf.Variable([1000.])
with tf.GradientTape() as tape:
    z = my_better_softplus(x)
    
z, tape.gradient(z, [x])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1000.], dtype=float32)>,
#  [<tf.Tensor: shape=(1,), dtype=float32, numpy=array([nan], dtype=float32)>])
