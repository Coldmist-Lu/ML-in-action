# %% [markdown]
# ## 1 Callbacks

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[8]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])

# %% [markdown]
# ### 1-1 保存 checkpoint
#
# * 使用 save_best_only 参数可仅保存最好的模型

# %%
model.compile(loss='mse', optimizer=keras.optimizers.SGD(lr=1e-3))
checkpoint_cb = keras.callbacks.ModelCheckpoint('my_keras_model.h5', save_best_only=True)
history = model.fit(
    X_train, y_train, epochs=10, 
    validation_data=(X_valid, y_valid),
    callbacks=[checkpoint_cb]
)
model = keras.models.load_model('my_keras_model.h5')
mse_test = model.evaluate(X_test, y_test)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/10
# 11610/11610 [==============================] - 2s 191us/sample - loss: 1.8631 - val_loss: 3.2403
# Epoch 2/10
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.6723 - val_loss: 0.6939
# Epoch 3/10
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.5927 - val_loss: 0.5531
# Epoch 4/10
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.5550 - val_loss: 0.5519
# Epoch 5/10
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.5278 - val_loss: 0.5715
# Epoch 6/10
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.5032 - val_loss: 0.5591
# Epoch 7/10
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.4863 - val_loss: 0.4593
# Epoch 8/10
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.4701 - val_loss: 0.4651
# Epoch 9/10
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.4586 - val_loss: 0.4392
# Epoch 10/10
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.4476 - val_loss: 0.4257
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %% [markdown]
# ### 1-2 early stopping
#
# * patients：若多个轮次在验证集上都没有任何进展，则可以中断训练，回滚到最佳模型。
# * 下面的例子将两者结合，既保存了模型检查点，又在没有更多进展时中断训练。

# %%
model.compile(loss='mse', optimizer=keras.optimizers.SGD(lr=1e-3))
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid), 
                    callbacks=[checkpoint_cb, early_stopping_cb])
model.evaluate(X_test, y_test, verbose=0)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 2s 149us/sample - loss: 0.4388 - val_loss: 0.4122
# Epoch 2/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.4319 - val_loss: 0.4046
# Epoch 3/100
# Epoch 33/100
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.3578 - val_loss: 0.3388
# Epoch 34/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3567 - val_loss: 0.3542
# Epoch 35/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3559 - val_loss: 0.3429
# Epoch 36/100
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.3550 - val_loss: 0.3372
# Epoch 37/100
# 11610/11610 [==============================] - 1s 112us/sample - loss: 0.3540 - val_loss: 0.3815
# Epoch 38/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3535 - val_loss: 0.3610
# Epoch 39/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3526 - val_loss: 0.3331
# Epoch 40/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3518 - val_loss: 0.3451
# Epoch 41/100
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3511 - val_loss: 0.3587
# Epoch 42/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3506 - val_loss: 0.3305
# Epoch 43/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3497 - val_loss: 0.3714
# Epoch 44/100
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.3493 - val_loss: 0.3290
# Epoch 45/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3485 - val_loss: 0.3876
# Epoch 46/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3480 - val_loss: 0.3419
# Epoch 47/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3473 - val_loss: 0.3268
# Epoch 48/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.3468 - val_loss: 0.3281
# Epoch 49/100
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3458 - val_loss: 0.3585
# Epoch 50/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3456 - val_loss: 0.3545
# Epoch 51/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3451 - val_loss: 0.3433
# Epoch 52/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3447 - val_loss: 0.3314
# Epoch 53/100
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3439 - val_loss: 0.3733
# Epoch 54/100
# 11610/11610 [==============================] - 1s 113us/sample - loss: 0.3435 - val_loss: 0.3286
# Epoch 55/100
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3430 - val_loss: 0.3345
# Epoch 56/100
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.3425 - val_loss: 0.3303
# Epoch 57/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3420 - val_loss: 0.3650
# 0.34665875379429306

# %% [markdown]
# ### 1-3 custom callbacks
#
# * 例子是输出验证损失和训练损失间的比率以防止过拟合。

# %%
class PrintValTrainRatioCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        print('\nval/train: {:.2f}'.format(logs['val_loss'] / logs['loss']))

# %%
val_train_ratio_cb = PrintValTrainRatioCallback()
history = model.fit(X_train, y_train, epochs=10, 
                    validation_data=(X_valid, y_valid), 
                    callbacks=[val_train_ratio_cb])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/10
# 11104/11610 [===========================>..] - ETA: 0s - loss: 0.3449
# val/train: 1.10
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3465 - val_loss: 0.3825
# Epoch 2/10
# 11200/11610 [===========================>..] - ETA: 0s - loss: 0.3462
# val/train: 0.94
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3463 - val_loss: 0.3262
# Epoch 3/10
# 11072/11610 [===========================>..] - ETA: 0s - loss: 0.3474
# val/train: 1.00
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3457 - val_loss: 0.3446
# Epoch 4/10
# 11584/11610 [============================>.] - ETA: 0s - loss: 0.3456
# val/train: 0.96
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3450 - val_loss: 0.3318
# Epoch 5/10
# 11296/11610 [============================>.] - ETA: 0s - loss: 0.3462
# val/train: 0.95
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.3445 - val_loss: 0.3271
# Epoch 6/10
# 11424/11610 [============================>.] - ETA: 0s - loss: 0.3454
# val/train: 1.06
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3439 - val_loss: 0.3639
# Epoch 7/10
# 11488/11610 [============================>.] - ETA: 0s - loss: 0.3442
# val/train: 0.95
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.3434 - val_loss: 0.3253
# Epoch 8/10
# 11424/11610 [============================>.] - ETA: 0s - loss: 0.3437
# val/train: 1.15
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3430 - val_loss: 0.3953
# Epoch 9/10
# 11136/11610 [===========================>..] - ETA: 0s - loss: 0.3465
# val/train: 0.96
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3426 - val_loss: 0.3293
# Epoch 10/10
# 11392/11610 [============================>.] - ETA: 0s - loss: 0.3426
# val/train: 0.96
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3420 - val_loss: 0.3287

# %% [markdown]
# ## 2-TensorBoard

# %%
import os

root_logdir = os.path.join(os.curdir, 'my_logs')

def get_run_logdir():
    import time
    run_id = time.strftime('run_%Y_%m_%d-%H_%M_%S')
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()
run_logdir
# Out:
# './my_logs/run_2021_07_14-13_45_44'

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[8]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])    
model.compile(loss='mse', optimizer=keras.optimizers.SGD(lr=1e-3))
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid),
                    callbacks=[tensorboard_cb])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 2s 190us/sample - loss: 1.8631 - val_loss: 3.2403
# Epoch 2/30
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.6723 - val_loss: 0.6939
# Epoch 3/30
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.5927 - val_loss: 0.5531
# Epoch 4/30
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.5550 - val_loss: 0.5519
# Epoch 5/30
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.5278 - val_loss: 0.5715
# Epoch 6/30
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.5032 - val_loss: 0.5591
# Epoch 7/30
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.4863 - val_loss: 0.4593
# Epoch 8/30
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.4701 - val_loss: 0.4651
# Epoch 9/30
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.4586 - val_loss: 0.4392
# Epoch 10/30
# 11610/11610 [==============================] - 1s 125us/sample - loss: 0.4476 - val_loss: 0.4257
# Epoch 11/30
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.4391 - val_loss: 0.4122
# Epoch 12/30
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.4316 - val_loss: 0.4052
# Epoch 13/30
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.4255 - val_loss: 0.4025
# Epoch 14/30
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.4203 - val_loss: 0.3962
# Epoch 15/30
# 11610/11610 [==============================] - 1s 126us/sample - loss: 0.4154 - val_loss: 0.3906
# Epoch 16/30
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.4110 - val_loss: 0.3923
# Epoch 17/30
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.4076 - val_loss: 0.3851
# Epoch 18/30
# 11610/11610 [==============================] - 1s 124us/sample - loss: 0.4036 - val_loss: 0.3802
# Epoch 19/30
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.4007 - val_loss: 0.3744
# Epoch 20/30
# 11610/11610 [==============================] - 1s 124us/sample - loss: 0.3976 - val_loss: 0.3716
# Epoch 21/30
# 11610/11610 [==============================] - 1s 127us/sample - loss: 0.3950 - val_loss: 0.3709
# Epoch 22/30
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.3922 - val_loss: 0.3663
# Epoch 23/30
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3896 - val_loss: 0.3668
# Epoch 24/30
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.3874 - val_loss: 0.3627
# Epoch 25/30
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.3850 - val_loss: 0.3675
# Epoch 26/30
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3826 - val_loss: 0.3703
# Epoch 27/30
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.3807 - val_loss: 0.3560
# Epoch 28/30
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.3784 - val_loss: 0.3667
# Epoch 29/30
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.3764 - val_loss: 0.3634
# Epoch 30/30
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3746 - val_loss: 0.3514

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_logs --port=6006 --host 10.193.211.136
# Out:
#       <iframe id="tensorboard-frame-9723f5d699df7617" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9723f5d699df7617");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
